# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score,f1_score, recall_score, precision_score, average_precision_score, balanced_accuracy_score
import baselines as b
from sklearn.utils import resample

# %%
#data=pd.read_csv('./data/score_1.csv')
# print(data.head(3))
# gt=pd.read_json('./data/gts_5.json').T
# cand=pd.read_json('./data/res_5.json').T
# gt=gt.reset_index(drop=True)


# cand=cand.reset_index(drop=True)
# #print(data.columns)

def MRA_stats():
#    
    data=pd.read_csv('/Users/zaheerbabar/Documents/Python/chexpert_labeler_operations/MRA_Files/score_1.csv')
    data=data.sample(frac=1)
    #print(type(data),type(filenames))
    scores_bleu=[]
    for i in range(0,1000):
        print(i)
        res = resample(data, n_samples=240, replace=True)
        
        res=res.reset_index()
        
        bleus,_,_,_=b.all_scores(list(res['ref']),list(res['cand']))
        
        scores_bleu.append(round(float(bleus[0]),3))

       
    co_scores['MRA_shuffle']=scores_bleu
    
    co_scores.to_csv('co_MRA_Shuffle.csv')
    
    
MRA_stats()
def SAT_ref_fetch():
    path1='./data/impression-findings/'
    sample=[2,3,4,5]
    for i in sample:
        
        test=pd.read_csv(path1+'Sample'+str(i)+'/test.csv')
        train=pd.read_csv(path1+'Sample'+str(i)+'/train.csv')
        test_labelled=pd.read_csv(path1+'Sample'+str(i)+'/test_labelled.csv')
        train_labelled=pd.read_csv(path1+'Sample'+str(i)+'/train_labelled.csv')
        
        
        
        scores=pd.read_csv(path+'score'+str(i)+'.csv')
        print(scores.shape)
        
        
        #print(test['report_id'])
        
        #print(test[test['report_id'] in scores['REPORT_ID']])
        #print(scores['REPORT_ID'])
        labels=[]
        for j in list(scores['REPORT_ID']):
            if j in list(test['report_id']):
                index=list(test['report_id']).index(j)
                labels.append(test_labelled.iloc[index,:])
            else:
                index=list(train['report_id']).index(j)
                labels.append(train_labelled.iloc[index,:])
                
        data=pd.DataFrame(labels)    
        print(data.head(3))  
        data.to_csv('cand_labelled'+str(i)+'.csv')    
        #labels=[list(test['report_id']).index(i) for i in list(scores['REPORT_ID']) if i in list(test['report_id'])]

    
#SAT_ref_fetch()
# Out:
# 0
# {'testlen': 14391, 'reflen': 9409, 'guess': [14391, 14151, 13911, 13671], 'correct': [4044, 1664, 757, 271]}
# ratio: 1.5294930385799204
# 1
# {'testlen': 14463, 'reflen': 9087, 'guess': [14463, 14223, 13983, 13743], 'correct': [4003, 1622, 733, 266]}
# ratio: 1.5916143941893262
# 2
# {'testlen': 14379, 'reflen': 9142, 'guess': [14379, 14139, 13899, 13659], 'correct': [4044, 1666, 749, 258]}
# ratio: 1.5728505797416787
# 3
# {'testlen': 14521, 'reflen': 9622, 'guess': [14521, 14281, 14041, 13801], 'correct': [4084, 1666, 753, 275]}
# ratio: 1.509145707752909
# 4
# {'testlen': 14557, 'reflen': 9505, 'guess': [14557, 14317, 14077, 13837], 'correct': [4175, 1741, 804, 283]}
# ratio: 1.5315097317199862
# 5
# {'testlen': 14520, 'reflen': 8800, 'guess': [14520, 14280, 14040, 13800], 'correct': [4033, 1720, 818, 329]}
# ratio: 1.6499999999998125
# 6
# {'testlen': 14474, 'reflen': 9125, 'guess': [14474, 14234, 13994, 13754], 'correct': [4168, 1781, 839, 324]}
# ratio: 1.5861917808217438
# 7
# {'testlen': 14468, 'reflen': 8956, 'guess': [14468, 14228, 13988, 13748], 'correct': [4115, 1722, 789, 294]}
# ratio: 1.6154533273781135
# 8
# {'testlen': 14364, 'reflen': 8845, 'guess': [14364, 14124, 13884, 13644], 'correct': [4109, 1791, 868, 325]}
# ratio: 1.6239683436968202
# 9
# {'testlen': 14394, 'reflen': 8816, 'guess': [14394, 14154, 13914, 13674], 'correct': [3908, 1614, 745, 298]}
# ratio: 1.6327132486386533
# 10
# {'testlen': 14314, 'reflen': 9473, 'guess': [14314, 14074, 13834, 13594], 'correct': [4074, 1657, 761, 276]}
# ratio: 1.5110313522641705
# 11
# {'testlen': 14627, 'reflen': 9842, 'guess': [14627, 14387, 14147, 13907], 'correct': [4212, 1725, 752, 262]}
# ratio: 1.4861816703920456
# 12
# {'testlen': 14353, 'reflen': 8971, 'guess': [14353, 14113, 13873, 13633], 'correct': [4038, 1646, 755, 269]}
# ratio: 1.5999331178239216
# 13
# {'testlen': 14386, 'reflen': 9175, 'guess': [14386, 14146, 13906, 13666], 'correct': [4077, 1703, 800, 302]}
# ratio: 1.5679564032695839
# 14
# {'testlen': 14572, 'reflen': 9128, 'guess': [14572, 14332, 14092, 13852], 'correct': [3930, 1642, 776, 303]}
# ratio: 1.5964066608236638
# 15
# {'testlen': 14321, 'reflen': 9388, 'guess': [14321, 14081, 13841, 13601], 'correct': [4095, 1725, 823, 315]}
# ratio: 1.5254580315294497
# 16
# {'testlen': 14457, 'reflen': 9017, 'guess': [14457, 14217, 13977, 13737], 'correct': [4030, 1710, 784, 283]}
# ratio: 1.6033048685813902
# 17
# {'testlen': 14558, 'reflen': 9368, 'guess': [14558, 14318, 14078, 13838], 'correct': [3971, 1612, 720, 248]}
# ratio: 1.554013663535274
# 18
# {'testlen': 14310, 'reflen': 8980, 'guess': [14310, 14070, 13830, 13590], 'correct': [4087, 1711, 789, 292]}
# ratio: 1.5935412026724283
# 19
# {'testlen': 14553, 'reflen': 8802, 'guess': [14553, 14313, 14073, 13833], 'correct': [4093, 1753, 828, 321]}
# ratio: 1.6533742331286465
# 20
# {'testlen': 14449, 'reflen': 9223, 'guess': [14449, 14209, 13969, 13729], 'correct': [4163, 1741, 796, 280]}
# ratio: 1.5666269109832411
# 21
# {'testlen': 14428, 'reflen': 9336, 'guess': [14428, 14188, 13948, 13708], 'correct': [4171, 1752, 831, 342]}
# ratio: 1.5454155955439646
# 22
# {'testlen': 14443, 'reflen': 8715, 'guess': [14443, 14203, 13963, 13723], 'correct': [3978, 1654, 779, 305]}
# ratio: 1.6572576018357248
# 23
# {'testlen': 14467, 'reflen': 9266, 'guess': [14467, 14227, 13987, 13747], 'correct': [4053, 1690, 767, 284]}
# ratio: 1.561299374055519
# 24
# {'testlen': 14319, 'reflen': 9232, 'guess': [14319, 14079, 13839, 13599], 'correct': [3993, 1661, 792, 334]}
# ratio: 1.5510181975734887
# 25
# {'testlen': 14436, 'reflen': 9238, 'guess': [14436, 14196, 13956, 13716], 'correct': [4131, 1742, 819, 317]}
# ratio: 1.5626759038751286
# 26
# {'testlen': 14308, 'reflen': 9300, 'guess': [14308, 14068, 13828, 13588], 'correct': [4034, 1650, 745, 272]}
# ratio: 1.5384946236557484
# 27
# {'testlen': 14500, 'reflen': 9390, 'guess': [14500, 14260, 14020, 13780], 'correct': [4126, 1747, 832, 313]}
# ratio: 1.5441959531414755
# 28
# {'testlen': 14598, 'reflen': 9348, 'guess': [14598, 14358, 14118, 13878], 'correct': [4009, 1633, 728, 272]}
# ratio: 1.561617458279679
# 29
# {'testlen': 14379, 'reflen': 9066, 'guess': [14379, 14139, 13899, 13659], 'correct': [4089, 1735, 824, 316]}
# ratio: 1.586035737921731
# 30
# {'testlen': 14263, 'reflen': 8844, 'guess': [14263, 14023, 13783, 13543], 'correct': [4061, 1699, 803, 315]}
# ratio: 1.612731795567434
# 31
# {'testlen': 14260, 'reflen': 9309, 'guess': [14260, 14020, 13780, 13540], 'correct': [4060, 1639, 751, 279]}
# ratio: 1.5318508969812512
# 32
# {'testlen': 14429, 'reflen': 9162, 'guess': [14429, 14189, 13949, 13709], 'correct': [4046, 1692, 787, 298]}
# ratio: 1.5748744815540738
# 33
# {'testlen': 14292, 'reflen': 9514, 'guess': [14292, 14052, 13812, 13572], 'correct': [4070, 1677, 777, 295]}
# ratio: 1.5022072734915384
# 34
# {'testlen': 14518, 'reflen': 9655, 'guess': [14518, 14278, 14038, 13798], 'correct': [4324, 1836, 862, 333]}
# ratio: 1.50367685137219
# 35
# {'testlen': 14366, 'reflen': 9199, 'guess': [14366, 14126, 13886, 13646], 'correct': [4156, 1718, 773, 267]}
# ratio: 1.5616914882050699
# 36
# {'testlen': 14530, 'reflen': 9065, 'guess': [14530, 14290, 14050, 13810], 'correct': [3961, 1661, 756, 273]}
# ratio: 1.602868174296569
# 37
# {'testlen': 14312, 'reflen': 9418, 'guess': [14312, 14072, 13832, 13592], 'correct': [4233, 1784, 842, 309]}
# ratio: 1.5196432363557528
# 38
# {'testlen': 14453, 'reflen': 9307, 'guess': [14453, 14213, 13973, 13733], 'correct': [4179, 1757, 823, 298]}
# ratio: 1.5529171591273714
# 39
# {'testlen': 14418, 'reflen': 9322, 'guess': [14418, 14178, 13938, 13698], 'correct': [4068, 1687, 783, 286]}
# ratio: 1.5466638060500377
# 40
# {'testlen': 14407, 'reflen': 9324, 'guess': [14407, 14167, 13927, 13687], 'correct': [4141, 1745, 830, 328]}
# ratio: 1.5451522951521293
# 41
# {'testlen': 14345, 'reflen': 9227, 'guess': [14345, 14105, 13865, 13625], 'correct': [4074, 1717, 795, 289]}
# ratio: 1.5546764929010994
# 42
# {'testlen': 14465, 'reflen': 9355, 'guess': [14465, 14225, 13985, 13745], 'correct': [4064, 1652, 767, 296]}
# ratio: 1.5462319615177396
# 43
# {'testlen': 14338, 'reflen': 8580, 'guess': [14338, 14098, 13858, 13618], 'correct': [4019, 1730, 816, 300]}
# ratio: 1.6710955710953763
# 44
# {'testlen': 14675, 'reflen': 9108, 'guess': [14675, 14435, 14195, 13955], 'correct': [4086, 1702, 769, 268]}
# ratio: 1.6112209046989885
# 45
# {'testlen': 14281, 'reflen': 8947, 'guess': [14281, 14041, 13801, 13561], 'correct': [4089, 1755, 839, 337]}
# ratio: 1.5961774896611605
# 46
# {'testlen': 14427, 'reflen': 8785, 'guess': [14427, 14187, 13947, 13707], 'correct': [4046, 1690, 770, 273]}
# ratio: 1.6422310756970242
# 47
# {'testlen': 14368, 'reflen': 8899, 'guess': [14368, 14128, 13888, 13648], 'correct': [3954, 1654, 765, 292]}
# ratio: 1.6145634340935369
# 48
# {'testlen': 14668, 'reflen': 9381, 'guess': [14668, 14428, 14188, 13948], 'correct': [4123, 1743, 800, 290]}
# ratio: 1.5635859716446472
# 49
# {'testlen': 14492, 'reflen': 9154, 'guess': [14492, 14252, 14012, 13772], 'correct': [4137, 1739, 814, 321]}
# ratio: 1.5831330565871111
# 50
# {'testlen': 14395, 'reflen': 8999, 'guess': [14395, 14155, 13915, 13675], 'correct': [4049, 1730, 810, 296]}
# ratio: 1.5996221802420714
# 51
# {'testlen': 14351, 'reflen': 9143, 'guess': [14351, 14111, 13871, 13631], 'correct': [4099, 1685, 751, 260]}
# ratio: 1.5696160997482698
# 52
# {'testlen': 14275, 'reflen': 8968, 'guess': [14275, 14035, 13795, 13555], 'correct': [4135, 1748, 807, 294]}
# ratio: 1.5917707404101704
# 53
# {'testlen': 14305, 'reflen': 8953, 'guess': [14305, 14065, 13825, 13585], 'correct': [4004, 1638, 740, 253]}
# ratio: 1.5977884507984363
# 54
# {'testlen': 14318, 'reflen': 9225, 'guess': [14318, 14078, 13838, 13598], 'correct': [4127, 1752, 817, 301]}
# ratio: 1.5520867208670404
# 55
# {'testlen': 14592, 'reflen': 9242, 'guess': [14592, 14352, 14112, 13872], 'correct': [4075, 1660, 767, 261]}
# ratio: 1.5788790305127052
# 56
# {'testlen': 14527, 'reflen': 9058, 'guess': [14527, 14287, 14047, 13807], 'correct': [4115, 1811, 897, 371]}
# ratio: 1.6037756679176856
# 57
# {'testlen': 14472, 'reflen': 8901, 'guess': [14472, 14232, 13992, 13752], 'correct': [4084, 1703, 789, 293]}
# ratio: 1.6258847320523957
# 58
# {'testlen': 14625, 'reflen': 8804, 'guess': [14625, 14385, 14145, 13905], 'correct': [4182, 1779, 851, 321]}
# ratio: 1.6611767378462448
# 59
# {'testlen': 14372, 'reflen': 9492, 'guess': [14372, 14132, 13892, 13652], 'correct': [4242, 1802, 871, 350]}
# ratio: 1.5141171512851332
# 60
# {'testlen': 14230, 'reflen': 8933, 'guess': [14230, 13990, 13750, 13510], 'correct': [4058, 1708, 793, 292]}
# ratio: 1.5929698869359012
# 61
# {'testlen': 14446, 'reflen': 8924, 'guess': [14446, 14206, 13966, 13726], 'correct': [3964, 1603, 722, 236]}
# ratio: 1.6187808157774968
# 62
# {'testlen': 14480, 'reflen': 9169, 'guess': [14480, 14240, 14000, 13760], 'correct': [3985, 1613, 741, 268]}
# ratio: 1.5792343767039394
# 63
# {'testlen': 14332, 'reflen': 9263, 'guess': [14332, 14092, 13852, 13612], 'correct': [4138, 1758, 812, 301]}
# ratio: 1.5472309187086746
# 64
# {'testlen': 14321, 'reflen': 9552, 'guess': [14321, 14081, 13841, 13601], 'correct': [4334, 1846, 890, 343]}
# ratio: 1.4992671691790724
# 65
# {'testlen': 14451, 'reflen': 9187, 'guess': [14451, 14211, 13971, 13731], 'correct': [4185, 1774, 830, 322]}
# ratio: 1.5729835637311882
# 66
# {'testlen': 14403, 'reflen': 9108, 'guess': [14403, 14163, 13923, 13683], 'correct': [4203, 1792, 832, 305]}
# ratio: 1.5813570487481794
# 67
# {'testlen': 14401, 'reflen': 9162, 'guess': [14401, 14161, 13921, 13681], 'correct': [4199, 1776, 833, 323]}
# ratio: 1.5718183802661458
# 68
# {'testlen': 14589, 'reflen': 9058, 'guess': [14589, 14349, 14109, 13869], 'correct': [4066, 1710, 798, 307]}
# ratio: 1.610620446014395
# 69
# {'testlen': 14539, 'reflen': 9636, 'guess': [14539, 14299, 14059, 13819], 'correct': [4255, 1759, 807, 315]}
# ratio: 1.5088210875880543
# 70
# {'testlen': 14378, 'reflen': 9258, 'guess': [14378, 14138, 13898, 13658], 'correct': [4113, 1777, 856, 348]}
# ratio: 1.5530352127887714
# 71
# {'testlen': 14237, 'reflen': 8920, 'guess': [14237, 13997, 13757, 13517], 'correct': [4000, 1651, 773, 295]}
# ratio: 1.5960762331836775
# 72
# {'testlen': 14296, 'reflen': 9188, 'guess': [14296, 14056, 13816, 13576], 'correct': [4118, 1724, 809, 280]}
# ratio: 1.555942533739491
# 73
# {'testlen': 14605, 'reflen': 9226, 'guess': [14605, 14365, 14125, 13885], 'correct': [4125, 1735, 812, 302]}
# ratio: 1.5830262302187748
# 74
# {'testlen': 14264, 'reflen': 9442, 'guess': [14264, 14024, 13784, 13544], 'correct': [4293, 1803, 862, 345]}
# ratio: 1.5106968862527526
# 75
# {'testlen': 14472, 'reflen': 8655, 'guess': [14472, 14232, 13992, 13752], 'correct': [4042, 1687, 792, 295]}
# ratio: 1.6720970537259765
# 76
# {'testlen': 14343, 'reflen': 9178, 'guess': [14343, 14103, 13863, 13623], 'correct': [4100, 1739, 823, 311]}
# ratio: 1.5627587709738981
# 77
# {'testlen': 14440, 'reflen': 9086, 'guess': [14440, 14200, 13960, 13720], 'correct': [4099, 1707, 769, 279]}
# ratio: 1.589258199427516
# 78
# {'testlen': 14344, 'reflen': 9172, 'guess': [14344, 14104, 13864, 13624], 'correct': [4019, 1708, 786, 286]}
# ratio: 1.5638901003051064
# 79
# {'testlen': 14531, 'reflen': 8858, 'guess': [14531, 14291, 14051, 13811], 'correct': [4110, 1737, 804, 311]}
# ratio: 1.6404380221267056
# 80
# {'testlen': 14452, 'reflen': 9156, 'guess': [14452, 14212, 13972, 13732], 'correct': [3848, 1562, 725, 276]}
# ratio: 1.5784185233724795
# 81
# {'testlen': 14382, 'reflen': 9617, 'guess': [14382, 14142, 13902, 13662], 'correct': [4221, 1741, 791, 278]}
# ratio: 1.4954767599041805
# 82
# {'testlen': 14376, 'reflen': 8943, 'guess': [14376, 14136, 13896, 13656], 'correct': [4157, 1792, 854, 344]}
# ratio: 1.6075142569605716
# 83
# {'testlen': 14420, 'reflen': 8779, 'guess': [14420, 14180, 13940, 13700], 'correct': [4061, 1739, 822, 290]}
# ratio: 1.6425560997833872
# 84
# {'testlen': 14504, 'reflen': 9274, 'guess': [14504, 14264, 14024, 13784], 'correct': [4074, 1707, 804, 303]}
# ratio: 1.5639422040110453
# 85
# {'testlen': 14436, 'reflen': 9760, 'guess': [14436, 14196, 13956, 13716], 'correct': [4206, 1712, 762, 257]}
# ratio: 1.479098360655586
# 86
# {'testlen': 14340, 'reflen': 9116, 'guess': [14340, 14100, 13860, 13620], 'correct': [4098, 1703, 790, 297]}
# ratio: 1.5730583589291824
# 87
# {'testlen': 14511, 'reflen': 8734, 'guess': [14511, 14271, 14031, 13791], 'correct': [3888, 1598, 728, 254]}
# ratio: 1.6614380581633086
# 88
# {'testlen': 14615, 'reflen': 9045, 'guess': [14615, 14375, 14135, 13895], 'correct': [4100, 1727, 790, 296]}
# ratio: 1.615809839690258
# 89
# {'testlen': 14558, 'reflen': 9160, 'guess': [14558, 14318, 14078, 13838], 'correct': [4099, 1762, 859, 342]}
# ratio: 1.5893013100434945
# 90
# {'testlen': 14266, 'reflen': 8895, 'guess': [14266, 14026, 13786, 13546], 'correct': [4024, 1666, 795, 305]}
# ratio: 1.6038223721189877
# 91
# {'testlen': 14435, 'reflen': 9458, 'guess': [14435, 14195, 13955, 13715], 'correct': [4201, 1752, 834, 307]}
# ratio: 1.526221188411765
# 92
# {'testlen': 14548, 'reflen': 9492, 'guess': [14548, 14308, 14068, 13828], 'correct': [4193, 1763, 806, 290]}
# ratio: 1.5326590813314862
# 93
# {'testlen': 14534, 'reflen': 9135, 'guess': [14534, 14294, 14054, 13814], 'correct': [4021, 1625, 745, 276]}
# ratio: 1.591023535850948
# 94
# {'testlen': 14588, 'reflen': 9294, 'guess': [14588, 14348, 14108, 13868], 'correct': [4238, 1797, 832, 302]}
# ratio: 1.5696148052505303
# 95
# {'testlen': 14403, 'reflen': 8996, 'guess': [14403, 14163, 13923, 13683], 'correct': [4052, 1649, 770, 283]}
# ratio: 1.601044908848199
# 96
# {'testlen': 14645, 'reflen': 9207, 'guess': [14645, 14405, 14165, 13925], 'correct': [4098, 1736, 797, 292]}
# ratio: 1.590637558379321
# 97
# {'testlen': 14302, 'reflen': 9471, 'guess': [14302, 14062, 13822, 13582], 'correct': [4166, 1709, 769, 265]}
# ratio: 1.5100834125222773
# 98
# {'testlen': 14386, 'reflen': 9048, 'guess': [14386, 14146, 13906, 13666], 'correct': [4062, 1711, 783, 291]}
# ratio: 1.5899646330679056
# 99
# {'testlen': 14485, 'reflen': 8529, 'guess': [14485, 14245, 14005, 13765], 'correct': [4012, 1677, 762, 286]}
# ratio: 1.6983233673347755
# 100
# {'testlen': 14334, 'reflen': 9623, 'guess': [14334, 14094, 13854, 13614], 'correct': [4126, 1706, 749, 267]}
# ratio: 1.4895562714328703
# 101
# {'testlen': 14314, 'reflen': 9645, 'guess': [14314, 14074, 13834, 13594], 'correct': [4038, 1631, 750, 277]}
# ratio: 1.4840850181439622
# 102
# {'testlen': 14593, 'reflen': 8856, 'guess': [14593, 14353, 14113, 13873], 'correct': [3937, 1604, 723, 258]}
# ratio: 1.6478093947604282
# 103
# {'testlen': 14246, 'reflen': 9130, 'guess': [14246, 14006, 13766, 13526], 'correct': [4240, 1782, 829, 308]}
# ratio: 1.5603504928804424
# 104
# {'testlen': 14415, 'reflen': 9541, 'guess': [14415, 14175, 13935, 13695], 'correct': [4142, 1712, 772, 277]}
# ratio: 1.5108479195051345
# 105
# {'testlen': 14339, 'reflen': 9507, 'guess': [14339, 14099, 13859, 13619], 'correct': [4071, 1669, 744, 272]}
# ratio: 1.5082570737349839
# 106
# {'testlen': 14394, 'reflen': 9115, 'guess': [14394, 14154, 13914, 13674], 'correct': [4054, 1661, 755, 276]}
# ratio: 1.5791552386174899
# 107
# {'testlen': 14355, 'reflen': 9296, 'guess': [14355, 14115, 13875, 13635], 'correct': [4105, 1684, 767, 261]}
# ratio: 1.5442125645437237
# 108
# {'testlen': 14275, 'reflen': 9286, 'guess': [14275, 14035, 13795, 13555], 'correct': [4121, 1708, 776, 276]}
# ratio: 1.5372603919877732
# 109
# {'testlen': 14448, 'reflen': 9830, 'guess': [14448, 14208, 13968, 13728], 'correct': [4147, 1697, 770, 294]}
# ratio: 1.4697863682602776
# 110
# {'testlen': 14499, 'reflen': 8896, 'guess': [14499, 14259, 14019, 13779], 'correct': [4135, 1774, 838, 337]}
# ratio: 1.6298336330933418
# 111
# {'testlen': 14295, 'reflen': 8942, 'guess': [14295, 14055, 13815, 13575], 'correct': [4030, 1700, 816, 322]}
# ratio: 1.5986356519792442
# 112
# {'testlen': 14498, 'reflen': 9226, 'guess': [14498, 14258, 14018, 13778], 'correct': [4185, 1746, 817, 312]}
# ratio: 1.571428571428401
# 113
# {'testlen': 14846, 'reflen': 9115, 'guess': [14846, 14606, 14366, 14126], 'correct': [4019, 1685, 783, 317]}
# ratio: 1.6287438288533593
# 114
# {'testlen': 14517, 'reflen': 8812, 'guess': [14517, 14277, 14037, 13797], 'correct': [3973, 1667, 772, 278]}
# ratio: 1.6474126191555098
# 115
# {'testlen': 14407, 'reflen': 8967, 'guess': [14407, 14167, 13927, 13687], 'correct': [3952, 1612, 721, 245]}
# ratio: 1.6066688970668443
# 116
# {'testlen': 14349, 'reflen': 9008, 'guess': [14349, 14109, 13869, 13629], 'correct': [3957, 1631, 777, 317]}
# ratio: 1.592917406749379
# 117
# {'testlen': 14287, 'reflen': 8985, 'guess': [14287, 14047, 13807, 13567], 'correct': [4103, 1712, 796, 288]}
# ratio: 1.5900946021144584
# 118
# {'testlen': 14359, 'reflen': 9257, 'guess': [14359, 14119, 13879, 13639], 'correct': [4147, 1703, 792, 295]}
# ratio: 1.5511504807171275
# 119
# {'testlen': 14456, 'reflen': 9647, 'guess': [14456, 14216, 13976, 13736], 'correct': [4182, 1786, 821, 311]}
# ratio: 1.4984969420543692
# 120
# {'testlen': 14470, 'reflen': 9546, 'guess': [14470, 14230, 13990, 13750], 'correct': [4122, 1639, 741, 274]}
# ratio: 1.5158181437249616
# 121
# {'testlen': 14375, 'reflen': 8959, 'guess': [14375, 14135, 13895, 13655], 'correct': [4180, 1816, 860, 331]}
# ratio: 1.6045317557761352
# 122
# {'testlen': 14650, 'reflen': 9166, 'guess': [14650, 14410, 14170, 13930], 'correct': [4030, 1669, 742, 259]}
# ratio: 1.5982980580404103
# 123
# {'testlen': 14506, 'reflen': 8773, 'guess': [14506, 14266, 14026, 13786], 'correct': [4076, 1740, 816, 315]}
# ratio: 1.6534822751622416
# 124
# {'testlen': 14343, 'reflen': 9151, 'guess': [14343, 14103, 13863, 13623], 'correct': [4113, 1740, 829, 333]}
# ratio: 1.5673696863729025
# 125
# {'testlen': 14545, 'reflen': 9385, 'guess': [14545, 14305, 14065, 13825], 'correct': [4310, 1835, 856, 315]}
# ratio: 1.5498135322321203
# 126
# {'testlen': 14448, 'reflen': 8543, 'guess': [14448, 14208, 13968, 13728], 'correct': [4100, 1754, 814, 298]}
# ratio: 1.6912091771038638
# 127
# {'testlen': 14391, 'reflen': 9078, 'guess': [14391, 14151, 13911, 13671], 'correct': [4115, 1680, 775, 287]}
# ratio: 1.5852610707202484
# 128
# {'testlen': 14532, 'reflen': 8901, 'guess': [14532, 14292, 14052, 13812], 'correct': [4117, 1752, 818, 314]}
# ratio: 1.6326255476910871
# 129
# {'testlen': 14455, 'reflen': 9059, 'guess': [14455, 14215, 13975, 13735], 'correct': [4114, 1775, 859, 325]}
# ratio: 1.5956507340764328
# 130
# {'testlen': 14188, 'reflen': 9099, 'guess': [14188, 13948, 13708, 13468], 'correct': [4016, 1615, 721, 267]}
# ratio: 1.5592922299152039
# 131
# {'testlen': 14280, 'reflen': 9046, 'guess': [14280, 14040, 13800, 13560], 'correct': [4114, 1665, 741, 252]}
# ratio: 1.5785982754807009
# 132
# {'testlen': 14373, 'reflen': 9520, 'guess': [14373, 14133, 13893, 13653], 'correct': [4167, 1723, 806, 315]}
# ratio: 1.5097689075628666
# 133
# {'testlen': 14632, 'reflen': 9306, 'guess': [14632, 14392, 14152, 13912], 'correct': [4070, 1703, 797, 317]}
# ratio: 1.5723189340208927
# 134
# {'testlen': 14555, 'reflen': 8712, 'guess': [14555, 14315, 14075, 13835], 'correct': [4002, 1666, 760, 277]}
# ratio: 1.6706841138657402
# 135
# {'testlen': 14375, 'reflen': 9107, 'guess': [14375, 14135, 13895, 13655], 'correct': [4247, 1850, 889, 348]}
# ratio: 1.5784561326450446
# 136
# {'testlen': 14363, 'reflen': 8831, 'guess': [14363, 14123, 13883, 13643], 'correct': [4146, 1750, 810, 302]}
# ratio: 1.6264296229190773
# 137
# {'testlen': 14413, 'reflen': 9014, 'guess': [14413, 14173, 13933, 13693], 'correct': [4095, 1712, 803, 320]}
# ratio: 1.5989571777233638
# 138
# {'testlen': 14330, 'reflen': 9140, 'guess': [14330, 14090, 13850, 13610], 'correct': [4133, 1731, 803, 279]}
# ratio: 1.567833698030463
# 139
# {'testlen': 14364, 'reflen': 8809, 'guess': [14364, 14124, 13884, 13644], 'correct': [3888, 1611, 740, 274]}
# ratio: 1.630605063003561
# 140
# {'testlen': 14477, 'reflen': 9533, 'guess': [14477, 14237, 13997, 13757], 'correct': [4139, 1758, 828, 291]}
# ratio: 1.5186195321513145
# 141
# {'testlen': 14692, 'reflen': 9628, 'guess': [14692, 14452, 14212, 13972], 'correct': [4130, 1719, 782, 286]}
# ratio: 1.525965932696144
# 142
# {'testlen': 14340, 'reflen': 9361, 'guess': [14340, 14100, 13860, 13620], 'correct': [4133, 1717, 801, 298]}
# ratio: 1.531887618843977
# 143
# {'testlen': 14293, 'reflen': 9264, 'guess': [14293, 14053, 13813, 13573], 'correct': [4180, 1739, 817, 317]}
# ratio: 1.5428540587217678
# 144
# {'testlen': 14917, 'reflen': 9474, 'guess': [14917, 14677, 14437, 14197], 'correct': [4091, 1667, 774, 289]}
# ratio: 1.5745197382307816
# 145
# {'testlen': 14717, 'reflen': 9489, 'guess': [14717, 14477, 14237, 13997], 'correct': [4103, 1723, 810, 306]}
# ratio: 1.5509537359045682
# 146
# {'testlen': 14393, 'reflen': 8704, 'guess': [14393, 14153, 13913, 13673], 'correct': [4189, 1802, 846, 316]}
# ratio: 1.6536075367645158
# 147
# {'testlen': 14347, 'reflen': 9467, 'guess': [14347, 14107, 13867, 13627], 'correct': [4056, 1701, 807, 322]}
# ratio: 1.5154748072249375
# 148
# {'testlen': 14424, 'reflen': 8943, 'guess': [14424, 14184, 13944, 13704], 'correct': [3956, 1621, 753, 289]}
# ratio: 1.6128815833611077
# 149
# {'testlen': 14356, 'reflen': 9121, 'guess': [14356, 14116, 13876, 13636], 'correct': [4027, 1629, 732, 248]}
# ratio: 1.5739502247558848
# 150
# {'testlen': 14535, 'reflen': 9417, 'guess': [14535, 14295, 14055, 13815], 'correct': [4197, 1776, 819, 299]}
# ratio: 1.5434851863649204
# 151
# {'testlen': 14471, 'reflen': 9028, 'guess': [14471, 14231, 13991, 13751], 'correct': [4139, 1668, 735, 248]}
# ratio: 1.6029020824101015
# 152
# {'testlen': 14585, 'reflen': 8887, 'guess': [14585, 14345, 14105, 13865], 'correct': [4111, 1695, 772, 273]}
# ratio: 1.6411612467647527
# 153
# {'testlen': 14364, 'reflen': 9148, 'guess': [14364, 14124, 13884, 13644], 'correct': [4135, 1729, 799, 295]}
# ratio: 1.5701792741581142
# 154
# {'testlen': 14566, 'reflen': 9223, 'guess': [14566, 14326, 14086, 13846], 'correct': [4046, 1725, 827, 328]}
# ratio: 1.5793125880948087
# 155
# {'testlen': 14422, 'reflen': 9400, 'guess': [14422, 14182, 13942, 13702], 'correct': [4114, 1726, 784, 289]}
# ratio: 1.534255319148773
# 156
# {'testlen': 14532, 'reflen': 9400, 'guess': [14532, 14292, 14052, 13812], 'correct': [4120, 1733, 821, 318]}
# ratio: 1.5459574468083461
# 157
# {'testlen': 14541, 'reflen': 9015, 'guess': [14541, 14301, 14061, 13821], 'correct': [4129, 1650, 715, 239]}
# ratio: 1.6129783693841804
# 158
# {'testlen': 14271, 'reflen': 9204, 'guess': [14271, 14031, 13791, 13551], 'correct': [4130, 1750, 812, 319]}
# ratio: 1.5505215123857505
# 159
# {'testlen': 14463, 'reflen': 9098, 'guess': [14463, 14223, 13983, 13743], 'correct': [4172, 1796, 860, 321]}
# ratio: 1.5896900417672466
# 160
# {'testlen': 14482, 'reflen': 9384, 'guess': [14482, 14242, 14002, 13762], 'correct': [4120, 1756, 840, 334]}
# ratio: 1.543265132139648
# 161
# {'testlen': 14296, 'reflen': 9462, 'guess': [14296, 14056, 13816, 13576], 'correct': [4053, 1677, 770, 277]}
# ratio: 1.5108856478544164
# 162
# {'testlen': 14496, 'reflen': 9291, 'guess': [14496, 14256, 14016, 13776], 'correct': [4125, 1681, 760, 258]}
# ratio: 1.5602195673230481
# 163
# {'testlen': 14440, 'reflen': 9206, 'guess': [14440, 14200, 13960, 13720], 'correct': [4027, 1639, 756, 282]}
# ratio: 1.5685422550508832
# 164
# {'testlen': 14366, 'reflen': 9097, 'guess': [14366, 14126, 13886, 13646], 'correct': [4060, 1735, 816, 311]}
# ratio: 1.5792019347035748
# 165
# {'testlen': 14499, 'reflen': 9318, 'guess': [14499, 14259, 14019, 13779], 'correct': [4131, 1742, 801, 293]}
# ratio: 1.556020605279936
# 166
# {'testlen': 14502, 'reflen': 9108, 'guess': [14502, 14262, 14022, 13782], 'correct': [4083, 1744, 815, 314]}
# ratio: 1.5922266139655694
# 167
# {'testlen': 14557, 'reflen': 8999, 'guess': [14557, 14317, 14077, 13837], 'correct': [4056, 1676, 765, 269]}
# ratio: 1.6176241804643163
# 168
# {'testlen': 14364, 'reflen': 9435, 'guess': [14364, 14124, 13884, 13644], 'correct': [4169, 1717, 806, 298]}
# ratio: 1.5224165341810787
# 169
# {'testlen': 14281, 'reflen': 9330, 'guess': [14281, 14041, 13801, 13561], 'correct': [4127, 1723, 790, 294]}
# ratio: 1.5306538049301681
# 170
# {'testlen': 14418, 'reflen': 8950, 'guess': [14418, 14178, 13938, 13698], 'correct': [4066, 1664, 749, 266]}
# ratio: 1.610949720670211
# 171
# {'testlen': 14467, 'reflen': 9312, 'guess': [14467, 14227, 13987, 13747], 'correct': [4099, 1701, 768, 275]}
# ratio: 1.5535867697592833
# 172
# {'testlen': 14405, 'reflen': 8837, 'guess': [14405, 14165, 13925, 13685], 'correct': [4051, 1731, 823, 322]}
# ratio: 1.6300780807964659
# 173
# {'testlen': 14236, 'reflen': 9063, 'guess': [14236, 13996, 13756, 13516], 'correct': [4068, 1711, 800, 300]}
# ratio: 1.5707823016659417
# 174
# {'testlen': 14455, 'reflen': 9097, 'guess': [14455, 14215, 13975, 13735], 'correct': [4030, 1720, 816, 324]}
# ratio: 1.5889853797953621
# 175
# {'testlen': 14441, 'reflen': 8872, 'guess': [14441, 14201, 13961, 13721], 'correct': [4056, 1685, 762, 254]}
# ratio: 1.627705139765371
# 176
# {'testlen': 14539, 'reflen': 9170, 'guess': [14539, 14299, 14059, 13819], 'correct': [4102, 1665, 737, 261]}
# ratio: 1.585496183205934
# 177
# {'testlen': 14419, 'reflen': 9130, 'guess': [14419, 14179, 13939, 13699], 'correct': [4070, 1682, 768, 289]}
# ratio: 1.5792990142386003
# 178
# {'testlen': 14627, 'reflen': 9427, 'guess': [14627, 14387, 14147, 13907], 'correct': [4061, 1656, 752, 287]}
# ratio: 1.5516070860293252
# 179
# {'testlen': 14367, 'reflen': 9218, 'guess': [14367, 14127, 13887, 13647], 'correct': [3968, 1616, 742, 277]}
# ratio: 1.5585810371011544
# 180
# {'testlen': 14220, 'reflen': 9320, 'guess': [14220, 13980, 13740, 13500], 'correct': [4026, 1661, 786, 289]}
# ratio: 1.5257510729612096
# 181
# {'testlen': 14509, 'reflen': 9196, 'guess': [14509, 14269, 14029, 13789], 'correct': [4242, 1817, 841, 311]}
# ratio: 1.5777511961720772
# 182
# {'testlen': 14338, 'reflen': 9036, 'guess': [14338, 14098, 13858, 13618], 'correct': [4130, 1740, 795, 295]}
# ratio: 1.5867640548913693
# 183
# {'testlen': 14464, 'reflen': 9656, 'guess': [14464, 14224, 13984, 13744], 'correct': [4119, 1725, 798, 319]}
# ratio: 1.4979287489642192
# 184
# {'testlen': 14489, 'reflen': 9252, 'guess': [14489, 14249, 14009, 13769], 'correct': [4038, 1640, 723, 259]}
# ratio: 1.5660397751835746
# 185
# {'testlen': 14352, 'reflen': 9338, 'guess': [14352, 14112, 13872, 13632], 'correct': [4069, 1712, 819, 326]}
# ratio: 1.5369458128077171
# 186
# {'testlen': 14329, 'reflen': 8856, 'guess': [14329, 14089, 13849, 13609], 'correct': [3953, 1677, 792, 316]}
# ratio: 1.6179990966574505
# 187
# {'testlen': 14316, 'reflen': 9509, 'guess': [14316, 14076, 13836, 13596], 'correct': [4231, 1796, 865, 350]}
# ratio: 1.5055210852874639
# 188
# {'testlen': 14245, 'reflen': 9210, 'guess': [14245, 14005, 13765, 13525], 'correct': [4047, 1637, 719, 237]}
# ratio: 1.5466883821931001
# 189
# {'testlen': 14330, 'reflen': 8915, 'guess': [14330, 14090, 13850, 13610], 'correct': [4158, 1743, 817, 289]}
# ratio: 1.6074032529442952
# 190
# {'testlen': 14408, 'reflen': 9103, 'guess': [14408, 14168, 13928, 13688], 'correct': [4114, 1705, 789, 298]}
# ratio: 1.5827749093703631
# 191
# {'testlen': 14607, 'reflen': 9203, 'guess': [14607, 14367, 14127, 13887], 'correct': [4036, 1676, 770, 276]}
# ratio: 1.5871998261434763
# 192
# {'testlen': 14406, 'reflen': 9247, 'guess': [14406, 14166, 13926, 13686], 'correct': [4065, 1704, 800, 308]}
# ratio: 1.5579106737318527
# 193
# {'testlen': 14404, 'reflen': 9102, 'guess': [14404, 14164, 13924, 13684], 'correct': [4036, 1662, 766, 284]}
# ratio: 1.5825093386067257
# 194
# {'testlen': 14300, 'reflen': 8966, 'guess': [14300, 14060, 13820, 13580], 'correct': [4116, 1788, 856, 328]}
# ratio: 1.5949141200087447
# 195
# {'testlen': 14399, 'reflen': 8521, 'guess': [14399, 14159, 13919, 13679], 'correct': [4016, 1646, 751, 267]}
# ratio: 1.689825137894415
# 196
# {'testlen': 14689, 'reflen': 8661, 'guess': [14689, 14449, 14209, 13969], 'correct': [3976, 1715, 818, 308]}
# ratio: 1.6959935342337262
# 197
# {'testlen': 14342, 'reflen': 9227, 'guess': [14342, 14102, 13862, 13622], 'correct': [4100, 1745, 834, 315]}
# ratio: 1.5543513601385548
# 198
# {'testlen': 14900, 'reflen': 9119, 'guess': [14900, 14660, 14420, 14180], 'correct': [4071, 1725, 809, 301]}
# ratio: 1.633951091128234
# 199
# {'testlen': 14376, 'reflen': 8935, 'guess': [14376, 14136, 13896, 13656], 'correct': [4006, 1676, 747, 257]}
# ratio: 1.608953553441342
# 200
# {'testlen': 14362, 'reflen': 9159, 'guess': [14362, 14122, 13882, 13642], 'correct': [4073, 1702, 790, 287]}
# ratio: 1.5680751173707208
# 201
# {'testlen': 14301, 'reflen': 9486, 'guess': [14301, 14061, 13821, 13581], 'correct': [4113, 1710, 792, 288]}
# ratio: 1.5075901328271655
# 202
# {'testlen': 14234, 'reflen': 9551, 'guess': [14234, 13994, 13754, 13514], 'correct': [4149, 1705, 791, 288]}
# ratio: 1.4903151502458913
# 203
# {'testlen': 14566, 'reflen': 9041, 'guess': [14566, 14326, 14086, 13846], 'correct': [4149, 1740, 791, 280]}
# ratio: 1.6111049662646155
# 204
# {'testlen': 14312, 'reflen': 9018, 'guess': [14312, 14072, 13832, 13592], 'correct': [4006, 1680, 770, 290]}
# ratio: 1.5870481259701057
# 205
# {'testlen': 14283, 'reflen': 9325, 'guess': [14283, 14043, 13803, 13563], 'correct': [3954, 1607, 730, 291]}
# ratio: 1.531689008042731
# 206
# {'testlen': 14436, 'reflen': 9188, 'guess': [14436, 14196, 13956, 13716], 'correct': [4064, 1682, 791, 319]}
# ratio: 1.5711797997386185
# 207
# {'testlen': 14253, 'reflen': 9374, 'guess': [14253, 14013, 13773, 13533], 'correct': [4072, 1720, 809, 309]}
# ratio: 1.5204821847662129
# 208
# {'testlen': 14345, 'reflen': 9239, 'guess': [14345, 14105, 13865, 13625], 'correct': [4038, 1689, 777, 276]}
# ratio: 1.5526572139840293
# 209
# {'testlen': 14085, 'reflen': 8802, 'guess': [14085, 13845, 13605, 13365], 'correct': [3916, 1624, 751, 288]}
# ratio: 1.6002044989773232
# 210
# {'testlen': 14601, 'reflen': 9436, 'guess': [14601, 14361, 14121, 13881], 'correct': [4245, 1794, 824, 301]}
# ratio: 1.5473717676980132
# 211
# {'testlen': 14318, 'reflen': 9241, 'guess': [14318, 14078, 13838, 13598], 'correct': [4164, 1762, 821, 308]}
# ratio: 1.5493994156474895
# 212
# {'testlen': 14423, 'reflen': 9357, 'guess': [14423, 14183, 13943, 13703], 'correct': [4134, 1741, 797, 304]}
# ratio: 1.541412845997484
# 213
# {'testlen': 14371, 'reflen': 9439, 'guess': [14371, 14131, 13891, 13651], 'correct': [4131, 1678, 756, 265]}
# ratio: 1.5225129780695494
# 214
# {'testlen': 14404, 'reflen': 9310, 'guess': [14404, 14164, 13924, 13684], 'correct': [4177, 1792, 874, 360]}
# ratio: 1.5471535982812517
# 215
# {'testlen': 14316, 'reflen': 9038, 'guess': [14316, 14076, 13836, 13596], 'correct': [4107, 1693, 780, 282]}
# ratio: 1.5839787563618517
# 216
# {'testlen': 14489, 'reflen': 9120, 'guess': [14489, 14249, 14009, 13769], 'correct': [4106, 1680, 771, 289]}
# ratio: 1.588706140350703
# 217
# {'testlen': 14526, 'reflen': 8858, 'guess': [14526, 14286, 14046, 13806], 'correct': [4103, 1755, 809, 305]}
# ratio: 1.6398735606229804
# 218
# {'testlen': 14533, 'reflen': 9142, 'guess': [14533, 14293, 14053, 13813], 'correct': [4110, 1722, 788, 275]}
# ratio: 1.589695908991294
# 219
# {'testlen': 14525, 'reflen': 9376, 'guess': [14525, 14285, 14045, 13805], 'correct': [4232, 1805, 870, 343]}
# ratio: 1.549168088737036
# 220
# {'testlen': 14568, 'reflen': 9682, 'guess': [14568, 14328, 14088, 13848], 'correct': [4167, 1756, 814, 301]}
# ratio: 1.5046478000411583
# 221
# {'testlen': 14384, 'reflen': 9068, 'guess': [14384, 14144, 13904, 13664], 'correct': [4129, 1694, 773, 299]}
# ratio: 1.5862373180412894
# 222
# {'testlen': 14547, 'reflen': 8874, 'guess': [14547, 14307, 14067, 13827], 'correct': [4009, 1670, 754, 273]}
# ratio: 1.6392832995265225
# 223
# {'testlen': 14241, 'reflen': 8906, 'guess': [14241, 14001, 13761, 13521], 'correct': [4071, 1706, 800, 302]}
# ratio: 1.5990343588590163
# 224
# {'testlen': 14493, 'reflen': 9190, 'guess': [14493, 14253, 14013, 13773], 'correct': [4149, 1736, 809, 297]}
# ratio: 1.577040261153256
# 225
# {'testlen': 14267, 'reflen': 9298, 'guess': [14267, 14027, 13787, 13547], 'correct': [4161, 1773, 818, 313]}
# ratio: 1.5344160034414351
# 226
# {'testlen': 14410, 'reflen': 9230, 'guess': [14410, 14170, 13930, 13690], 'correct': [4202, 1767, 826, 316]}
# ratio: 1.5612134344527018
# 227
# {'testlen': 14257, 'reflen': 9041, 'guess': [14257, 14017, 13777, 13537], 'correct': [4119, 1735, 788, 287]}
# ratio: 1.576927331047276
# 228
# {'testlen': 14483, 'reflen': 8972, 'guess': [14483, 14243, 14003, 13763], 'correct': [3996, 1626, 733, 271]}
# ratio: 1.614244315648505
# 229
# {'testlen': 14389, 'reflen': 9048, 'guess': [14389, 14149, 13909, 13669], 'correct': [3973, 1649, 726, 251]}
# ratio: 1.5902961980546428
# 230
# {'testlen': 14509, 'reflen': 9157, 'guess': [14509, 14269, 14029, 13789], 'correct': [4071, 1719, 792, 302]}
# ratio: 1.584470896581677
# 231
# {'testlen': 14327, 'reflen': 9356, 'guess': [14327, 14087, 13847, 13607], 'correct': [4054, 1633, 729, 246]}
# ratio: 1.5313168020519954
# 232
# {'testlen': 14392, 'reflen': 8839, 'guess': [14392, 14152, 13912, 13672], 'correct': [4080, 1764, 833, 316]}
# ratio: 1.6282384885166163
# 233
# {'testlen': 14343, 'reflen': 9013, 'guess': [14343, 14103, 13863, 13623], 'correct': [3991, 1653, 766, 300]}
# ratio: 1.5913680239652066
# 234
# {'testlen': 14363, 'reflen': 8901, 'guess': [14363, 14123, 13883, 13643], 'correct': [4124, 1763, 827, 307]}
# ratio: 1.6136389169754393
# 235
# {'testlen': 14516, 'reflen': 9413, 'guess': [14516, 14276, 14036, 13796], 'correct': [4237, 1834, 877, 351]}
# ratio: 1.5421225964090575

# %%
# cand=cand.iloc[:,0]


# #cand=data['cand']

# cand=cand.sample(frac=1)
# cand=list(cand)

# gt=list(gt.iloc[:,0])




# cand_new=[]

# #gt=data['ref']

# for i in cand:
    
#     cand_new.append(b.preprocess(i))
    
# print(len(cand_new))
# b.all_scores(gt,cand_new)
